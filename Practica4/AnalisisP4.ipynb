# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error
from scipy import constants

# %% [markdown]
# ## Parte 1 de la practica 4

# %%
#Obtengo datos para el efecto 
with open('200T.csv', mode='r') as archivo:
    ArchivoAbierto = csv.reader(archivo) #Usamos la biblioteca csv
    next(ArchivoAbierto,None)            #Me salto el primer renglón
    En200, T200 = [], []
    for renglon in ArchivoAbierto:
        if renglon[1] == '':
            next(ArchivoAbierto,None)
        else:
            En200.append(float(renglon[0]))
            T200.append(float(renglon[1]))
    En200 = np.array(En200)
    T200 = np.array(T200)

with open('182T.csv', mode='r') as archivo:
    ArchivoAbierto = csv.reader(archivo) #Usamos la biblioteca csv
    next(ArchivoAbierto,None)            #Me salto el primer renglón
    En182, T182 = [], []
    for renglon in ArchivoAbierto:
        if renglon[1] == '':
            next(ArchivoAbierto,None)
        else:
            En182.append(float(renglon[0]))
            T182.append(float(renglon[1]))
    En182 = np.array(En182)
    T182 = np.array(T182)

with open('162T.csv', mode='r') as archivo:
    ArchivoAbierto = csv.reader(archivo) #Usamos la biblioteca csv
    next(ArchivoAbierto,None)            #Me salto el primer renglón
    En162, T162 = [], []
    for renglon in ArchivoAbierto:
        if renglon[1] == '':
            next(ArchivoAbierto,None)
        else:
            En162.append(float(renglon[0]))
            T162.append(float(renglon[1]))
    En162 = np.array(En162)
    T162 = np.array(T162)

with open('142T.csv', mode='r') as archivo:
    ArchivoAbierto = csv.reader(archivo) #Usamos la biblioteca csv
    next(ArchivoAbierto,None)            #Me salto el primer renglón
    En142, T142 = [], []
    for renglon in ArchivoAbierto:
        if renglon[1] == '':
            next(ArchivoAbierto,None)
        else:
            En142.append(float(renglon[0]))
            T142.append(float(renglon[1]))
    En142 = np.array(En142)
    T142 = np.array(T142)

with open('101T.csv', mode='r') as archivo:
    ArchivoAbierto = csv.reader(archivo) #Usamos la biblioteca csv
    next(ArchivoAbierto,None)            #Me salto el primer renglón
    En101, T101 = [], []
    for renglon in ArchivoAbierto:
        if renglon[1] == '':
            next(ArchivoAbierto,None)
        else:
            En101.append(float(renglon[0]))
            T101.append(float(renglon[1]))
    En101 = np.array(En101)
    T101 = np.array(T101)

with open('60T.csv', mode='r') as archivo:
    ArchivoAbierto = csv.reader(archivo) #Usamos la biblioteca csv
    next(ArchivoAbierto,None)            #Me salto el primer renglón
    En101, T101 = [], []
    for renglon in ArchivoAbierto:
        if renglon[1] == '':
            next(ArchivoAbierto,None)
        else:
            En101.append(float(renglon[0]))
            T101.append(float(renglon[1]))
    En101 = np.array(En101)
    T101 = np.array(T101)

with open('31T.csv', mode='r') as archivo:
    ArchivoAbierto = csv.reader(archivo) #Usamos la biblioteca csv
    next(ArchivoAbierto,None)            #Me salto el primer renglón
    En31, T31 = [], []
    for renglon in ArchivoAbierto:
        if renglon[1] == '':
            next(ArchivoAbierto,None)
        else:
            En31.append(float(renglon[0]))
            T31.append(float(renglon[1]))
    En31 = np.array(En31)
    T31 = np.array(T31)

with open('10T.csv', mode='r') as archivo:
    ArchivoAbierto = csv.reader(archivo) #Usamos la biblioteca csv
    next(ArchivoAbierto,None)            #Me salto el primer renglón
    En10, T10 = [], []
    for renglon in ArchivoAbierto:
        if renglon[1] == '':
            next(ArchivoAbierto,None)
        else:
            En10.append(float(renglon[0]))
            T10.append(float(renglon[1]))
    En10 = np.array(En10)
    T10 = np.array(T10)
# Out:
# 1
# 3.15
# 1.2
# 2.64
# 1.4
# 2.31
# 1.8
# 1.87
# 2
# 1.72
# 2.3
# 1.55
# 2.6
# 1.395
# 3
# 1.255
# 3.3
# 1.18
# 3.6
# 1.115
# 4
# 1.06
# 4.5
# 1.01
# 5
# 0.98
# 5.5
# 0.975
# 6
# 0.976
# 7
# 1.005
# 8
# 1.045
# 9
# 1.075
# 10
# 1.01
# 12

# %%
d = 0.03 #m
v = d/T

plt.plot(En,v,'.',label='Mediciones')
plt.title('Gráfica a 200 Torr')
plt.ylabel(r'$v [m/s]$'), plt.xlabel(r'$E/n [Td]$')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Parte 2 de la practica 4

# %%
with open('2v.csv', mode='r') as archivo:
    ArchivoAbierto = csv.reader(archivo) #Usamos la biblioteca csv
    next(ArchivoAbierto,None)            #Me salto el primer renglón
    V2c, V2a, V2b = [], [], []
    for renglon in ArchivoAbierto:
        V2c.append(float(renglon[0]))
        V2a.append(float(renglon[1]))
        V2b.append(float(renglon[2]))

with open('3v.csv', mode='r') as archivo:
    ArchivoAbierto = csv.reader(archivo) #Usamos la biblioteca csv
    next(ArchivoAbierto,None)            #Me salto el primer renglón
    V3c, V3a, V3b = [], [], []
    for renglon in ArchivoAbierto:
        V3c.append(float(renglon[0]))
        V3a.append(float(renglon[1]))
        V3b.append(float(renglon[2]))

with open('4v.csv', mode='r') as archivo:
    ArchivoAbierto = csv.reader(archivo) #Usamos la biblioteca csv
    next(ArchivoAbierto,None)            #Me salto el primer renglón
    V4c, V4a, V4b = [], [], []
    for renglon in ArchivoAbierto:
        V4c.append(float(renglon[0]))
        V4a.append(float(renglon[1]))
        V4b.append(float(renglon[2]))

V2a = np.array(V2a)*-1
V2b = np.array(V2b)*-(1/10)
V3a = np.array(V3a)*-1
V3b = np.array(V3b)*-(1/10)
V4a = np.array(V4a)*-1
V4b = np.array(V4b)*-(1/10)

# %%
plt.plot(V2c,V2a,'.',label='Va')
plt.plot(V2c,V2b,'--x',label='Vb')
plt.title('Gráfica a Vf = 2v')
plt.xlabel(r'$V [Volts]$'), plt.ylabel(r'$ Vc [Volts]$')
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(V3c,V3a,'.',label='Va')
plt.plot(V3c,V3b,'-x',label='Vb')
plt.title('Gráfica a Vf = 3v')
plt.xlabel('V [Volts]'), plt.ylabel(' Vc [Volts]')
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(V4c,V4a,'.',label='Va')
plt.plot(V4c,V4b,'-x',label='Vb')
plt.title('Gráfica a Vf = 4v')
plt.xlabel('V [Volts]'), plt.ylabel(' Vc [Volts]')
plt.legend()
plt.grid()
plt.show()
